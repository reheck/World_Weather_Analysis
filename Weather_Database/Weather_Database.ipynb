# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_wthr_desc = city_weather["weather"][0]["description"]
           
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_wthr_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | crestview
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | roald
# Processing Record 5 of Set 1 | kholm
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | tambul
# City not found. Skipping...
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | nantai
# Processing Record 12 of Set 1 | bonavista
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | ancud
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | gunjur
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 1 | kattivakkam
# Processing Record 20 of Set 1 | faanui
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | tanabe
# Processing Record 24 of Set 1 | shingu
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | tiksi
# Processing Record 27 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 1 | babati
# Processing Record 30 of Set 1 | dentsville
# Processing Record 31 of Set 1 | paamiut
# Processing Record 32 of Set 1 | saint-philippe
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | sola
# Processing Record 36 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | bubaque
# Processing Record 41 of Set 1 | corby
# Processing Record 42 of Set 1 | tiarei
# Processing Record 43 of Set 1 | kruisfontein
# Processing Record 44 of Set 1 | monrovia
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 1 | zhigansk
# Processing Record 48 of Set 1 | lakes entrance
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | dingle
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | dodge city
# Processing Record 3 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 2 | perpignan
# Processing Record 5 of Set 2 | xai-xai
# Processing Record 6 of Set 2 | airai
# Processing Record 7 of Set 2 | labelle
# Processing Record 8 of Set 2 | chillicothe
# Processing Record 9 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 2 | plettenberg bay
# Processing Record 11 of Set 2 | severo-kurilsk
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | narasannapeta
# Processing Record 14 of Set 2 | lompoc
# Processing Record 15 of Set 2 | pavlodar
# Processing Record 16 of Set 2 | luderitz
# Processing Record 17 of Set 2 | nunchia
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | nanortalik
# Processing Record 20 of Set 2 | mashhad
# Processing Record 21 of Set 2 | mar del plata
# Processing Record 22 of Set 2 | kandrian
# Processing Record 23 of Set 2 | basco
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | thompson
# Processing Record 26 of Set 2 | havre-saint-pierre
# Processing Record 27 of Set 2 | coquimbo
# Processing Record 28 of Set 2 | vestmannaeyjar
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | barrow
# Processing Record 31 of Set 2 | nikolskoye
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | fairbanks
# Processing Record 34 of Set 2 | chake chake
# Processing Record 35 of Set 2 | panama
# Processing Record 36 of Set 2 | taunggyi
# Processing Record 37 of Set 2 | bom jesus
# Processing Record 38 of Set 2 | upernavik
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | port alfred
# Processing Record 41 of Set 2 | abong mbang
# Processing Record 42 of Set 2 | bukachacha
# Processing Record 43 of Set 2 | kununurra
# Processing Record 44 of Set 2 | teluk nibung
# Processing Record 45 of Set 2 | batagay
# Processing Record 46 of Set 2 | udachnyy
# Processing Record 47 of Set 2 | necochea
# Processing Record 48 of Set 2 | ca mau
# Processing Record 49 of Set 2 | trapani
# Processing Record 50 of Set 2 | yaransk
# Processing Record 1 of Set 3 | susuman
# Processing Record 2 of Set 3 | kavieng
# Processing Record 3 of Set 3 | katsuura
# Processing Record 4 of Set 3 | bluff
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | jamestown
# Processing Record 7 of Set 3 | cherskiy
# Processing Record 8 of Set 3 | saint-pierre
# Processing Record 9 of Set 3 | zhenhai
# Processing Record 10 of Set 3 | khatanga
# Processing Record 11 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 3 | ponta delgada
# Processing Record 13 of Set 3 | naze
# Processing Record 14 of Set 3 | praia da vitoria
# Processing Record 15 of Set 3 | bilma
# Processing Record 16 of Set 3 | upata
# Processing Record 17 of Set 3 | burica
# City not found. Skipping...
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | ilulissat
# Processing Record 20 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 3 | matara
# Processing Record 22 of Set 3 | hambantota
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | bengkulu
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | kashi
# Processing Record 27 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 3 | toora-khem
# Processing Record 29 of Set 3 | saskylakh
# Processing Record 30 of Set 3 | waingapu
# Processing Record 31 of Set 3 | iqaluit
# Processing Record 32 of Set 3 | hervey bay
# Processing Record 33 of Set 3 | ponta do sol
# Processing Record 34 of Set 3 | rena
# Processing Record 35 of Set 3 | muravlenko
# Processing Record 36 of Set 3 | mecca
# Processing Record 37 of Set 3 | ahipara
# Processing Record 38 of Set 3 | niimi
# Processing Record 39 of Set 3 | souillac
# Processing Record 40 of Set 3 | vestmanna
# Processing Record 41 of Set 3 | zhoucheng
# Processing Record 42 of Set 3 | lermontovka
# Processing Record 43 of Set 3 | contamana
# Processing Record 44 of Set 3 | asau
# Processing Record 45 of Set 3 | xinan
# Processing Record 46 of Set 3 | zhuhai
# Processing Record 47 of Set 3 | charlestown
# Processing Record 48 of Set 3 | malakal
# Processing Record 49 of Set 3 | frontera
# Processing Record 50 of Set 3 | kurilsk
# Processing Record 1 of Set 4 | bethel
# Processing Record 2 of Set 4 | tasiilaq
# Processing Record 3 of Set 4 | cockburn town
# Processing Record 4 of Set 4 | pedernales
# Processing Record 5 of Set 4 | carupano
# Processing Record 6 of Set 4 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 7 of Set 4 | trelew
# Processing Record 8 of Set 4 | bredasdorp
# Processing Record 9 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 4 | road town
# Processing Record 11 of Set 4 | port lincoln
# Processing Record 12 of Set 4 | hadejia
# Processing Record 13 of Set 4 | burnie
# Processing Record 14 of Set 4 | puerto colombia
# Processing Record 15 of Set 4 | kouango
# Processing Record 16 of Set 4 | saint-francois
# Processing Record 17 of Set 4 | hithadhoo
# Processing Record 18 of Set 4 | bedesa
# Processing Record 19 of Set 4 | grootfontein
# Processing Record 20 of Set 4 | gat
# Processing Record 21 of Set 4 | oranjestad
# Processing Record 22 of Set 4 | kosh-agach
# Processing Record 23 of Set 4 | toamasina
# Processing Record 24 of Set 4 | soller
# Processing Record 25 of Set 4 | bonito
# Processing Record 26 of Set 4 | meadow lake
# Processing Record 27 of Set 4 | krasnohrad
# Processing Record 28 of Set 4 | nyakabindi
# Processing Record 29 of Set 4 | chifeng
# Processing Record 30 of Set 4 | mayumba
# Processing Record 31 of Set 4 | salalah
# Processing Record 32 of Set 4 | belmonte
# Processing Record 33 of Set 4 | rocha
# Processing Record 34 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 35 of Set 4 | martapura
# Processing Record 36 of Set 4 | bon air
# Processing Record 37 of Set 4 | carnarvon
# Processing Record 38 of Set 4 | grand gaube
# Processing Record 39 of Set 4 | kahului
# Processing Record 40 of Set 4 | touros
# Processing Record 41 of Set 4 | hasaki
# Processing Record 42 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 4 | erenhot
# Processing Record 44 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 45 of Set 4 | ribeira grande
# Processing Record 46 of Set 4 | negotin
# Processing Record 47 of Set 4 | hofn
# Processing Record 48 of Set 4 | husavik
# Processing Record 49 of Set 4 | new norfolk
# Processing Record 50 of Set 4 | coihaique
# Processing Record 1 of Set 5 | provideniya
# Processing Record 2 of Set 5 | mehamn
# Processing Record 3 of Set 5 | mwanza
# Processing Record 4 of Set 5 | biograd na moru
# Processing Record 5 of Set 5 | santa maria do suacui
# Processing Record 6 of Set 5 | cheremukhovo
# Processing Record 7 of Set 5 | sainte-rose
# Processing Record 8 of Set 5 | severo-yeniseyskiy
# Processing Record 9 of Set 5 | pisco
# Processing Record 10 of Set 5 | luwuk
# Processing Record 11 of Set 5 | limay
# Processing Record 12 of Set 5 | soyo
# Processing Record 13 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 5 | moussoro
# Processing Record 15 of Set 5 | victoria
# Processing Record 16 of Set 5 | vila velha
# Processing Record 17 of Set 5 | ouadda
# Processing Record 18 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 5 | jacareacanga
# Processing Record 20 of Set 5 | yulara
# Processing Record 21 of Set 5 | clyde river
# Processing Record 22 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 5 | biak
# Processing Record 24 of Set 5 | jega
# Processing Record 25 of Set 5 | knysna
# Processing Record 26 of Set 5 | lata
# Processing Record 27 of Set 5 | kalmar
# Processing Record 28 of Set 5 | chengmai
# City not found. Skipping...
# Processing Record 29 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 5 | nyurba
# Processing Record 31 of Set 5 | aykhal
# Processing Record 32 of Set 5 | aklavik
# Processing Record 33 of Set 5 | maldonado
# Processing Record 34 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 5 | ulkan
# Processing Record 36 of Set 5 | grindavik
# Processing Record 37 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 5 | poum
# Processing Record 39 of Set 5 | san patricio
# Processing Record 40 of Set 5 | goundi
# Processing Record 41 of Set 5 | shelburne
# Processing Record 42 of Set 5 | la ronge
# Processing Record 43 of Set 5 | raposa
# Processing Record 44 of Set 5 | massakory
# Processing Record 45 of Set 5 | kajaani
# Processing Record 46 of Set 5 | haines junction
# Processing Record 47 of Set 5 | cayenne
# Processing Record 48 of Set 5 | rexburg
# Processing Record 49 of Set 5 | codrington
# Processing Record 50 of Set 5 | mauriti
# Processing Record 1 of Set 6 | florida
# Processing Record 2 of Set 6 | labuhan
# Processing Record 3 of Set 6 | vanimo
# Processing Record 4 of Set 6 | helong
# Processing Record 5 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 6 | kaeo
# Processing Record 7 of Set 6 | tiznit
# Processing Record 8 of Set 6 | mahibadhoo
# Processing Record 9 of Set 6 | muros
# Processing Record 10 of Set 6 | mogadishu
# Processing Record 11 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 6 | klaksvik
# Processing Record 13 of Set 6 | sinnamary
# Processing Record 14 of Set 6 | markopoulon
# City not found. Skipping...
# Processing Record 15 of Set 6 | mahebourg
# Processing Record 16 of Set 6 | esperance
# Processing Record 17 of Set 6 | iskateley
# Processing Record 18 of Set 6 | saquena
# Processing Record 19 of Set 6 | bud
# Processing Record 20 of Set 6 | tevaitoa
# Processing Record 21 of Set 6 | isangel
# Processing Record 22 of Set 6 | leningradskiy
# Processing Record 23 of Set 6 | mormugao
# Processing Record 24 of Set 6 | talnakh
# Processing Record 25 of Set 6 | amapa
# Processing Record 26 of Set 6 | kerewan
# Processing Record 27 of Set 6 | umm kaddadah
# Processing Record 28 of Set 6 | wanning
# Processing Record 29 of Set 6 | vidalia
# Processing Record 30 of Set 6 | kungsbacka
# Processing Record 31 of Set 6 | port-gentil
# Processing Record 32 of Set 6 | anloga
# Processing Record 33 of Set 6 | adrar
# Processing Record 34 of Set 6 | porbandar
# Processing Record 35 of Set 6 | southbridge
# Processing Record 36 of Set 6 | tambacounda
# Processing Record 37 of Set 6 | teguldet
# Processing Record 38 of Set 6 | nazarovo
# Processing Record 39 of Set 6 | orocue
# Processing Record 40 of Set 6 | sechura
# Processing Record 41 of Set 6 | san clemente
# Processing Record 42 of Set 6 | ostrovnoy
# Processing Record 43 of Set 6 | kendari
# Processing Record 44 of Set 6 | kingsville
# Processing Record 45 of Set 6 | skjervoy
# Processing Record 46 of Set 6 | port elizabeth
# Processing Record 47 of Set 6 | georgetown
# Processing Record 48 of Set 6 | uni
# Processing Record 49 of Set 6 | victor harbor
# Processing Record 50 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 7 | neiafu
# Processing Record 2 of Set 7 | okato
# Processing Record 3 of Set 7 | dikson
# Processing Record 4 of Set 7 | cidreira
# Processing Record 5 of Set 7 | farah
# Processing Record 6 of Set 7 | seoul
# Processing Record 7 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 7 | ulladulla
# Processing Record 9 of Set 7 | dunajska streda
# Processing Record 10 of Set 7 | sumisip
# Processing Record 11 of Set 7 | korla
# Processing Record 12 of Set 7 | callaway
# Processing Record 13 of Set 7 | snyder
# Processing Record 14 of Set 7 | inuvik
# Processing Record 15 of Set 7 | mogzon
# Processing Record 16 of Set 7 | guerrero negro
# Processing Record 17 of Set 7 | sao filipe
# Processing Record 18 of Set 7 | saldanha
# Processing Record 19 of Set 7 | cabo san lucas
# Processing Record 20 of Set 7 | lorengau
# Processing Record 21 of Set 7 | upington
# Processing Record 22 of Set 7 | srednekolymsk
# Processing Record 23 of Set 7 | gornopravdinsk
# Processing Record 24 of Set 7 | mount isa
# Processing Record 25 of Set 7 | uchaly
# Processing Record 26 of Set 7 | doha
# Processing Record 27 of Set 7 | resistencia
# Processing Record 28 of Set 7 | evensk
# Processing Record 29 of Set 7 | raga
# Processing Record 30 of Set 7 | usva
# City not found. Skipping...
# Processing Record 31 of Set 7 | freeport
# Processing Record 32 of Set 7 | taquari
# Processing Record 33 of Set 7 | lahij
# Processing Record 34 of Set 7 | ilhabela
# Processing Record 35 of Set 7 | panama city
# Processing Record 36 of Set 7 | turukhansk
# Processing Record 37 of Set 7 | canaries
# Processing Record 38 of Set 7 | coos bay
# Processing Record 39 of Set 7 | bridlington
# Processing Record 40 of Set 7 | tuatapere
# Processing Record 41 of Set 7 | zeya
# Processing Record 42 of Set 7 | sabha
# Processing Record 43 of Set 7 | samarai
# Processing Record 44 of Set 7 | quelimane
# Processing Record 45 of Set 7 | nome
# Processing Record 46 of Set 7 | najran
# Processing Record 47 of Set 7 | ambon
# Processing Record 48 of Set 7 | paragould
# Processing Record 49 of Set 7 | gazli
# Processing Record 50 of Set 7 | wilmington
# Processing Record 1 of Set 8 | college
# Processing Record 2 of Set 8 | dwarahat
# Processing Record 3 of Set 8 | bocanda
# Processing Record 4 of Set 8 | olafsvik
# Processing Record 5 of Set 8 | san isidro
# Processing Record 6 of Set 8 | batagay-alyta
# Processing Record 7 of Set 8 | whitehorse
# Processing Record 8 of Set 8 | buchanan
# Processing Record 9 of Set 8 | republic
# Processing Record 10 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 11 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 12 of Set 8 | ozernovskiy
# Processing Record 13 of Set 8 | anadyr
# Processing Record 14 of Set 8 | honiara
# Processing Record 15 of Set 8 | norwich
# Processing Record 16 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 8 | gizo
# Processing Record 18 of Set 8 | san pedro carcha
# Processing Record 19 of Set 8 | sambava
# Processing Record 20 of Set 8 | port hardy
# Processing Record 21 of Set 8 | asfi
# Processing Record 22 of Set 8 | griffith
# Processing Record 23 of Set 8 | raudeberg
# Processing Record 24 of Set 8 | pulandian
# Processing Record 25 of Set 8 | mount gambier
# Processing Record 26 of Set 8 | matsuura
# Processing Record 27 of Set 8 | sonepur
# Processing Record 28 of Set 8 | myanaung
# Processing Record 29 of Set 8 | vila
# Processing Record 30 of Set 8 | khorixas
# Processing Record 31 of Set 8 | emerald
# Processing Record 32 of Set 8 | kirakira
# Processing Record 33 of Set 8 | north battleford
# Processing Record 34 of Set 8 | geraldton
# Processing Record 35 of Set 8 | kaitangata
# Processing Record 36 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 8 | leh
# Processing Record 38 of Set 8 | macaravita
# Processing Record 39 of Set 8 | san cristobal
# Processing Record 40 of Set 8 | mahajanga
# Processing Record 41 of Set 8 | tura
# Processing Record 42 of Set 8 | hastings
# Processing Record 43 of Set 8 | faya
# Processing Record 44 of Set 8 | ukiah
# Processing Record 45 of Set 8 | los llanos de aridane
# Processing Record 46 of Set 8 | kyabe
# Processing Record 47 of Set 8 | yinchuan
# Processing Record 48 of Set 8 | a
# City not found. Skipping...
# Processing Record 49 of Set 8 | kerman
# Processing Record 50 of Set 8 | tromso
# Processing Record 1 of Set 9 | bonthe
# Processing Record 2 of Set 9 | sur
# Processing Record 3 of Set 9 | kyra
# Processing Record 4 of Set 9 | lewistown
# Processing Record 5 of Set 9 | salair
# Processing Record 6 of Set 9 | kargasok
# Processing Record 7 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 9 | kaa-khem
# Processing Record 9 of Set 9 | ayan
# Processing Record 10 of Set 9 | lasa
# Processing Record 11 of Set 9 | sehithwa
# Processing Record 12 of Set 9 | kalabo
# Processing Record 13 of Set 9 | warrnambool
# Processing Record 14 of Set 9 | yining
# Processing Record 15 of Set 9 | iberia
# Processing Record 16 of Set 9 | karratha
# Processing Record 17 of Set 9 | rorvik
# Processing Record 18 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 9 | okhotsk
# Processing Record 20 of Set 9 | kenai
# Processing Record 21 of Set 9 | laguna
# Processing Record 22 of Set 9 | plouzane
# Processing Record 23 of Set 9 | chara
# Processing Record 24 of Set 9 | villanueva de la serena
# Processing Record 25 of Set 9 | umkomaas
# Processing Record 26 of Set 9 | miranorte
# City not found. Skipping...
# Processing Record 27 of Set 9 | tabuk
# Processing Record 28 of Set 9 | alofi
# Processing Record 29 of Set 9 | muret
# Processing Record 30 of Set 9 | bollnas
# Processing Record 31 of Set 9 | darab
# Processing Record 32 of Set 9 | vao
# Processing Record 33 of Set 9 | namibe
# Processing Record 34 of Set 9 | carmarthen
# Processing Record 35 of Set 9 | sitka
# Processing Record 36 of Set 9 | constitucion
# Processing Record 37 of Set 9 | yar-sale
# Processing Record 38 of Set 9 | anshun
# Processing Record 39 of Set 9 | sao joao da barra
# Processing Record 40 of Set 9 | kunri
# Processing Record 41 of Set 9 | prince rupert
# Processing Record 42 of Set 9 | pevek
# Processing Record 43 of Set 9 | kourou
# Processing Record 44 of Set 9 | egvekinot
# Processing Record 45 of Set 9 | nianzishan
# Processing Record 46 of Set 9 | wanaka
# Processing Record 47 of Set 9 | matamoros
# Processing Record 48 of Set 9 | luganville
# Processing Record 49 of Set 9 | marzuq
# Processing Record 50 of Set 9 | kitui
# Processing Record 1 of Set 10 | unai
# Processing Record 2 of Set 10 | pskov
# Processing Record 3 of Set 10 | broome
# Processing Record 4 of Set 10 | pitimbu
# Processing Record 5 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 10 | chanute
# Processing Record 7 of Set 10 | te anau
# Processing Record 8 of Set 10 | kangasala
# Processing Record 9 of Set 10 | ivanava
# Processing Record 10 of Set 10 | atherton
# Processing Record 11 of Set 10 | volovo
# Processing Record 12 of Set 10 | sorbhog
# Processing Record 13 of Set 10 | broken hill
# Processing Record 14 of Set 10 | norman wells
# Processing Record 15 of Set 10 | gorontalo
# Processing Record 16 of Set 10 | grand-lahou
# Processing Record 17 of Set 10 | henties bay
# Processing Record 18 of Set 10 | malm
# Processing Record 19 of Set 10 | sawakin
# Processing Record 20 of Set 10 | beyneu
# Processing Record 21 of Set 10 | camacha
# Processing Record 22 of Set 10 | manokwari
# Processing Record 23 of Set 10 | bani
# Processing Record 24 of Set 10 | padang
# Processing Record 25 of Set 10 | cochabamba
# Processing Record 26 of Set 10 | oussouye
# Processing Record 27 of Set 10 | qena
# Processing Record 28 of Set 10 | oroville
# Processing Record 29 of Set 10 | waipawa
# Processing Record 30 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 10 | ormara
# Processing Record 32 of Set 10 | caucaia
# Processing Record 33 of Set 10 | bandarbeyla
# Processing Record 34 of Set 10 | richards bay
# Processing Record 35 of Set 10 | bay roberts
# Processing Record 36 of Set 10 | komsomolskiy
# Processing Record 37 of Set 10 | portland
# Processing Record 38 of Set 10 | chapais
# Processing Record 39 of Set 10 | loandjili
# Processing Record 40 of Set 10 | coahuayana
# Processing Record 41 of Set 10 | moerai
# Processing Record 42 of Set 10 | piacabucu
# Processing Record 43 of Set 10 | ilula
# Processing Record 44 of Set 10 | catuday
# Processing Record 45 of Set 10 | yuma
# Processing Record 46 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 10 | marsassoum
# Processing Record 48 of Set 10 | khandbari
# Processing Record 49 of Set 10 | flinders
# Processing Record 50 of Set 10 | kedrovyy
# Processing Record 1 of Set 11 | tenosique
# Processing Record 2 of Set 11 | buzmeyin
# Processing Record 3 of Set 11 | anchorage
# Processing Record 4 of Set 11 | elat
# Processing Record 5 of Set 11 | foshan
# Processing Record 6 of Set 11 | hagi
# Processing Record 7 of Set 11 | chokurdakh
# Processing Record 8 of Set 11 | we
# City not found. Skipping...
# Processing Record 9 of Set 11 | donji komren
# City not found. Skipping...
# Processing Record 10 of Set 11 | deputatskiy
# Processing Record 11 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 11 | nizwa
# Processing Record 13 of Set 11 | saurimo
# Processing Record 14 of Set 11 | lodja
# Processing Record 15 of Set 11 | rio gallegos
# Processing Record 16 of Set 11 | nizhnyaya tura
# Processing Record 17 of Set 11 | miandoab
# Processing Record 18 of Set 11 | chulman
# Processing Record 19 of Set 11 | tabou
# Processing Record 20 of Set 11 | kieta
# Processing Record 21 of Set 11 | itarema
# Processing Record 22 of Set 11 | siniscola
# Processing Record 23 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 24 of Set 11 | araouane
# Processing Record 25 of Set 11 | qaqortoq
# Processing Record 26 of Set 11 | kysyl-syr
# Processing Record 27 of Set 11 | port hedland
# Processing Record 28 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 29 of Set 11 | ajtos
# Processing Record 30 of Set 11 | opuwo
# Processing Record 31 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 11 | kangaatsiaq
# Processing Record 33 of Set 11 | katav-ivanovsk
# Processing Record 34 of Set 11 | goderich
# Processing Record 35 of Set 11 | limbang
# Processing Record 36 of Set 11 | rawah
# Processing Record 37 of Set 11 | athens
# Processing Record 38 of Set 11 | beira
# Processing Record 39 of Set 11 | pangnirtung
# Processing Record 40 of Set 11 | verkhoyansk
# Processing Record 41 of Set 11 | berikulskiy
# City not found. Skipping...
# Processing Record 42 of Set 11 | ixtapa
# Processing Record 43 of Set 11 | mount hagen
# Processing Record 44 of Set 11 | kavaratti
# Processing Record 45 of Set 11 | basoko
# Processing Record 46 of Set 11 | fort nelson
# Processing Record 47 of Set 11 | coolum beach
# Processing Record 48 of Set 11 | ankang
# Processing Record 49 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 11 | riachao das neves
# Processing Record 1 of Set 12 | asola
# Processing Record 2 of Set 12 | torres
# Processing Record 3 of Set 12 | cranbrook
# Processing Record 4 of Set 12 | yumen
# Processing Record 5 of Set 12 | diffa
# Processing Record 6 of Set 12 | itoman
# Processing Record 7 of Set 12 | voh
# Processing Record 8 of Set 12 | yeghegnut
# Processing Record 9 of Set 12 | winnipeg
# Processing Record 10 of Set 12 | dunedin
# Processing Record 11 of Set 12 | magdalena
# Processing Record 12 of Set 12 | sorong
# Processing Record 13 of Set 12 | ouango
# Processing Record 14 of Set 12 | omsukchan
# Processing Record 15 of Set 12 | takoradi
# Processing Record 16 of Set 12 | saint george
# Processing Record 17 of Set 12 | lokomotivnyy
# Processing Record 18 of Set 12 | schattdorf
# Processing Record 19 of Set 12 | issoire
# Processing Record 20 of Set 12 | hakvik
# City not found. Skipping...
# Processing Record 21 of Set 12 | chicama
# Processing Record 22 of Set 12 | koumac
# Processing Record 23 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 12 | zemio
# Processing Record 25 of Set 12 | eyl
# Processing Record 26 of Set 12 | elko
# Processing Record 27 of Set 12 | sorland
# Processing Record 28 of Set 12 | beringovskiy
# Processing Record 29 of Set 12 | kamen-rybolov
# Processing Record 30 of Set 12 | povenets
# Processing Record 31 of Set 12 | filadelfia
# Processing Record 32 of Set 12 | ketchikan
# Processing Record 33 of Set 12 | abnub
# Processing Record 34 of Set 12 | oktyabrskiy
# Processing Record 35 of Set 12 | sabak
# Processing Record 36 of Set 12 | taltal
# Processing Record 37 of Set 12 | ngama
# Processing Record 38 of Set 12 | betioky
# Processing Record 39 of Set 12 | palmer
# Processing Record 40 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 41 of Set 12 | wenceslau braz
# Processing Record 42 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 12 | tessalit
# Processing Record 44 of Set 12 | wakkanai
# Processing Record 45 of Set 12 | narsaq
# Processing Record 46 of Set 12 | grand-santi
# Processing Record 47 of Set 12 | university place
# Processing Record 48 of Set 12 | avera
# Processing Record 49 of Set 12 | hamilton
# Processing Record 50 of Set 12 | nemuro
# Processing Record 1 of Set 13 | davila
# Processing Record 2 of Set 13 | zhovkva
# Processing Record 3 of Set 13 | san jose
# Processing Record 4 of Set 13 | rodeo
# Processing Record 5 of Set 13 | cap malheureux
# Processing Record 6 of Set 13 | mezhdurechensk
# Processing Record 7 of Set 13 | manali
# Processing Record 8 of Set 13 | hualmay
# Processing Record 9 of Set 13 | sept-iles
# Processing Record 10 of Set 13 | aleksandrovskoye
# Processing Record 11 of Set 13 | hot springs
# Processing Record 12 of Set 13 | port macquarie
# Processing Record 13 of Set 13 | grande prairie
# Processing Record 14 of Set 13 | kiunga
# Processing Record 15 of Set 13 | teluk intan
# Processing Record 16 of Set 13 | river falls
# Processing Record 17 of Set 13 | alta floresta
# Processing Record 18 of Set 13 | teknaf
# Processing Record 19 of Set 13 | sar-e pul
# Processing Record 20 of Set 13 | mehran
# Processing Record 21 of Set 13 | bolshevo
# Processing Record 22 of Set 13 | yingzhong
# City not found. Skipping...
# Processing Record 23 of Set 13 | alamos
# Processing Record 24 of Set 13 | nouadhibou
# Processing Record 25 of Set 13 | saint-georges
# Processing Record 26 of Set 13 | tilichiki
# Processing Record 27 of Set 13 | pilao arcado
# City not found. Skipping...
# Processing Record 28 of Set 13 | saint-louis
# Processing Record 29 of Set 13 | belaya gora
# Processing Record 30 of Set 13 | nuuk
# Processing Record 31 of Set 13 | iseyin
# Processing Record 32 of Set 13 | makung
# City not found. Skipping...
# Processing Record 33 of Set 13 | coari
# Processing Record 34 of Set 13 | mvuma
# Processing Record 35 of Set 13 | batemans bay
# Processing Record 36 of Set 13 | palmerston
# Processing Record 37 of Set 13 | niihama
# Processing Record 38 of Set 13 | roma
# Processing Record 39 of Set 13 | sungai besar
# Processing Record 40 of Set 13 | montepuez
# Processing Record 41 of Set 13 | neryungri
# Processing Record 42 of Set 13 | yamada
# Processing Record 43 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 44 of Set 13 | sandwick
# Processing Record 45 of Set 13 | abu dhabi
# Processing Record 46 of Set 13 | kostomuksha
# Processing Record 47 of Set 13 | teya
# Processing Record 48 of Set 13 | bokoro
# Processing Record 49 of Set 13 | gonbad-e qabus
# Processing Record 50 of Set 13 | nalgonda
# Processing Record 1 of Set 14 | ayagoz
# Processing Record 2 of Set 14 | mabaruma
# Processing Record 3 of Set 14 | rawson
# Processing Record 4 of Set 14 | san jeronimo
# Processing Record 5 of Set 14 | oyon
# Processing Record 6 of Set 14 | ahuimanu
# Processing Record 7 of Set 14 | malyn
# Processing Record 8 of Set 14 | hirara
# Processing Record 9 of Set 14 | shellbrook
# Processing Record 10 of Set 14 | derzhavinsk
# Processing Record 11 of Set 14 | devavanya
# Processing Record 12 of Set 14 | maumere
# Processing Record 13 of Set 14 | tautira
# Processing Record 14 of Set 14 | ambilobe
# Processing Record 15 of Set 14 | mazatlan
# Processing Record 16 of Set 14 | riyadh
# Processing Record 17 of Set 14 | guamuchil
# Processing Record 18 of Set 14 | dukat
# Processing Record 19 of Set 14 | humaita
# Processing Record 20 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 21 of Set 14 | bhan
# Processing Record 22 of Set 14 | khandyga
# Processing Record 23 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 24 of Set 14 | berlin
# Processing Record 25 of Set 14 | bathsheba
# Processing Record 26 of Set 14 | miquelon
# Processing Record 27 of Set 14 | carrickfergus
# Processing Record 28 of Set 14 | lensk
# Processing Record 29 of Set 14 | mahon
# Processing Record 30 of Set 14 | am timan
# Processing Record 31 of Set 14 | sao pedro do piaui
# Processing Record 32 of Set 14 | yerbogachen
# Processing Record 33 of Set 14 | jawhar
# Processing Record 34 of Set 14 | shumskiy
# Processing Record 35 of Set 14 | santo tomas
# Processing Record 36 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 37 of Set 14 | balestrand
# Processing Record 38 of Set 14 | kongoussi
# Processing Record 39 of Set 14 | ruy barbosa
# Processing Record 40 of Set 14 | alcudia
# Processing Record 41 of Set 14 | svolvaer
# Processing Record 42 of Set 14 | pangai
# Processing Record 43 of Set 14 | fraga
# Processing Record 44 of Set 14 | boa vista
# Processing Record 45 of Set 14 | pineville
# Processing Record 46 of Set 14 | high prairie
# Processing Record 47 of Set 14 | acuna
# City not found. Skipping...
# Processing Record 48 of Set 14 | demba
# Processing Record 49 of Set 14 | madimba
# Processing Record 50 of Set 14 | fushan
# Processing Record 1 of Set 15 | karlskrona
# Processing Record 2 of Set 15 | bairiki
# Processing Record 3 of Set 15 | lagoa
# Processing Record 4 of Set 15 | tall kayf
# Processing Record 5 of Set 15 | toro
# Processing Record 6 of Set 15 | casper
# Processing Record 7 of Set 15 | kota tinggi
# Processing Record 8 of Set 15 | lere
# Processing Record 9 of Set 15 | borda da mata
# Processing Record 10 of Set 15 | bahia blanca
# Processing Record 11 of Set 15 | fortuna
# Processing Record 12 of Set 15 | valley city
# Processing Record 13 of Set 15 | vallenar
# Processing Record 14 of Set 15 | minas de barroteran
# Processing Record 15 of Set 15 | pokhara
# Processing Record 16 of Set 15 | kapoeta
# Processing Record 17 of Set 15 | saint-michel-des-saints
# Processing Record 18 of Set 15 | lavrentiya
# Processing Record 19 of Set 15 | marsa matruh
# Processing Record 20 of Set 15 | mtinko
# Processing Record 21 of Set 15 | tigwi
# City not found. Skipping...
# Processing Record 22 of Set 15 | peniche
# Processing Record 23 of Set 15 | guanay
# Processing Record 24 of Set 15 | churapcha
# Processing Record 25 of Set 15 | keti bandar
# Processing Record 26 of Set 15 | wanlaweyn
# Processing Record 27 of Set 15 | cassilandia
# Processing Record 28 of Set 15 | vilsbiburg
# Processing Record 29 of Set 15 | kalmunai
# Processing Record 30 of Set 15 | dhidhdhoo
# Processing Record 31 of Set 15 | mananara
# Processing Record 32 of Set 15 | buala
# Processing Record 33 of Set 15 | kerki
# City not found. Skipping...
# Processing Record 34 of Set 15 | balkanabat
# Processing Record 35 of Set 15 | paramonga
# Processing Record 36 of Set 15 | brae
# Processing Record 37 of Set 15 | biltine
# Processing Record 38 of Set 15 | nador
# Processing Record 39 of Set 15 | pueblo nuevo
# Processing Record 40 of Set 15 | alugan
# Processing Record 41 of Set 15 | vardo
# Processing Record 42 of Set 15 | cardston
# Processing Record 43 of Set 15 | aflu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Crestview      US  30.7621  -86.5705     78.04        71           0
# 1     Albany      US  42.6001  -73.9662     74.62        76          58
# 2    Rikitea      PF -23.1203 -134.9692     76.35        68           0
# 3      Roald      NO  62.5833    6.1333     49.91        71          20
# 4      Kholm      RU  59.2667   32.8500     59.61        38          98
#
#    Wind Speed Current Description                 Date
# 0        3.44           clear sky  2022-05-14 14:08:10
# 1        1.92       broken clouds  2022-05-14 13:58:02
# 2       21.92           clear sky  2022-05-14 14:11:22
# 3       23.02          few clouds  2022-05-14 14:11:23
# 4        8.23     overcast clouds  2022-05-14 14:11:23

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
